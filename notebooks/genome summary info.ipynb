# %%
import pandas as pd
import os
import glob
from collections import defaultdict
os.chdir('/data6/Angelo/alexcc/AngeloStrainsPaper/manuscript_materials/soil_popgen/notebooks')

# %%
final_table = defaultdict(list)
#genome names
f = open('../data_tables/names.txt')
f.readline()
for line in f.readlines():
    final_table['genomes'].append(line.split()[0])
    final_table['phylum'].append(line.split()[1].split("_")[0])
    final_table['label'].append(line.split()[1].split("_")[-1].strip())
f.close()

# %%
## Get relative abundance information

abunds = pd.read_csv('../data_tables/bin_reads.txt', sep="\t").sum()
total_reads = pd.read_csv('../data_tables/bin_total_reads.tsv', sep="\t")
total = int(total_reads['reads'].sum())

for name in final_table['genomes']:
    i = 0

    for sum in abunds:
    #     print(sum)
        if abunds.index[i] == name:
            final_table['abundance'].append(sum / total * 100)
            break
        i += 1

# %%
## Get SNP #'s (aa SNVs)
for name in final_table['genomes']:
    for fn in glob.glob('../data/all/snps/*.tsv'):
        if name in fn:
            break
            
    snps = pd.read_csv(fn, sep="\t")
    snps['varFreq'] = [eval(v)/(A + C + T + G) for A, C, T, G, v in zip(snps['A'], snps['C'], snps['T'], snps['G'], snps['varBase'])]    
    
    # count total
    final_table['SNPs'].append(len(snps.index))
    
    # count N and S
    snps_s = snps[snps.mutation_type == 'S']
    snps_n = snps[snps.mutation_type == 'N']
    final_table['N:S'].append(float(len(snps_n.index)) / float(len(snps_s.index)) )
    
    #  N mean MAF
    final_table['N_freq'].append(snps_n['varFreq'].mean())
    
    #  S mean MAF 
    final_table['S_freq'].append(snps_s['varFreq'].mean())

# %%
## Get mean linkages (for both N and S)

for name in final_table['genomes']:
    for fn in glob.glob('../data/all/linkage/*.tsv'):
        if name in fn:
            break
            
    snps = pd.read_csv(fn, sep="\t")

    snps_s = snps[(snps.mutation_type_A == 'S') & (snps.mutation_type_B == 'S')]
    snps_n = snps[(snps.mutation_type_A == 'N') & (snps.mutation_type_B == 'N')]

    final_table['r2'].append(snps['r2'].mean())
    final_table['d_prime'].append(snps['d_prime'].mean())
    final_table['r2_normalized'].append(snps['r2_normalized'].mean())
    final_table['d_prime_normalized'].append(snps['d_prime_normalized'].mean())

    final_table['r2_n'].append(snps_n['r2'].mean())
    final_table['d_prime_n'].append(snps_n['d_prime'].mean())

    final_table['r2_s'].append(snps_s['r2'].mean())
    final_table['d_prime_s'].append(snps_s['d_prime'].mean())

# %%
## Get mean microdiversity

for name in final_table['genomes']:
    for fn in glob.glob('../data/all/nuc_diversity/*.tsv'):
        if name in fn:
            break
            
    snps = pd.read_csv(fn, sep="\t")
    final_table['pi'].append(snps['pi'].mean())

# %%
## get genome sizes
f = open('../data_tables/genome_sizes.txt')
sizes = {}
for line in f.readlines():
    sizes[line.split()[0]] = int(line.split()[1].strip())
f.close()

for name in final_table['genomes']:
    final_table['genome_size'].append(sizes[name])

# %%
## Output final table 
final = pd.DataFrame(final_table)
final.to_csv('genome_summaries.txt')
final
# Out:
#                                           genomes               phylum  label  \
# 0         14_0903_05_40cm_Acidobacteria_477_57_13        Acidobacteria    477
# 1               14_0903_09_40cm_Bacteria_750_66_8     Dormibacteraeota    750
# 2              14_0927_12_40cm_Bacteria_6527_55_8      Verrucomicrobia   6527
# 3              14_0929_12_30cm_Bacteria_7383_54_8      Verrucomicrobia   7383
# 4             14_0927_05_20cm_Bacteria_2135_68_10          Chloroflexi   2135
# 5        14_0903_12_20cm_Proteobacteria_884_68_14  Gammaproteobacteria    884
# 6             14_1009_02_30cm_Bacteria_3696_55_11      Verrucomicrobia   3696
# 7         14_0929_02_40cm_Rokubacteria_2807_70_29         Rokubacteria   2807
# 8     14_0927_05_20cm_Gemmatimonadetes_2150_69_20     Gemmatimonadetes   2150
# 9     14_1009_02_30cm_Gemmatimonadetes_3684_69_12     Gemmatimonadetes   3684
# 10  14_0929_02_20cm_Deltaproteobacteria_2457_55_9  Deltaproteobacteria   2457
# 11      14_0929_09_30cm_Armatimonadetes_6837_65_8                ANGP1   6837
# 12        14_0903_02_20cm_Proteobacteria_56_68_14  Gammaproteobacteria     56
# 13           14_1009_16_30cm_Bacteria_10556_58_16        Acidobacteria  10556
# 14    14_1009_05_40cm_Gemmatimonadetes_4339_69_30     Gemmatimonadetes   4339
# 15    14_1009_02_40cm_Gemmatimonadetes_3801_70_15     Gemmatimonadetes   3801
# 16    14_1009_02_40cm_Gemmatimonadetes_3800_70_27     Gemmatimonadetes   3800
# 17            14_0929_09_20cm_Bacteria_6721_56_10      Verrucomicrobia   6721
# 18            14_1009_05_40cm_Bacteria_4402_54_13      Verrucomicrobia   4402
#
#     abundance    SNPs       N:S    N_freq    S_freq        r2   d_prime  \
# 0    0.095333   41659  0.815830  0.171854  0.175381  0.250134  0.908727
# 1    0.035341   88984  0.349681  0.225513  0.243178  0.250094  0.896740
# 2    0.051157   55032  0.694443  0.183401  0.179492  0.237439  0.889738
# 3    0.102463   79796  0.550088  0.175723  0.173406  0.230256  0.886380
# 4    0.054429   59047  0.391368  0.191591  0.205685  0.197282  0.853163
# 5    0.059495   92819  0.562269  0.203951  0.205105  0.293870  0.925962
# 6    0.064620   77282  0.635501  0.168618  0.174394  0.210280  0.906281
# 7    0.140153   93781  0.583001  0.162173  0.164737  0.165582  0.870571
# 8    0.209090  145222  0.391522  0.179465  0.182481  0.168366  0.915349
